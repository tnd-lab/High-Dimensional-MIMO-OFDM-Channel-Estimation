# %%
import sys
import os

# Get the parent directory of the notebook (project root)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from dotenv import load_dotenv

load_dotenv()

# %%
from src.ml.gen_data import synthesys_training_data, get_pilot_matrix

# %%
response_matrix, h_freq = synthesys_training_data()
pilot_matrix = get_pilot_matrix(response_matrix)

print(response_matrix.shape)
print(h_freq.shape)
print(pilot_matrix.shape)
# Out:
# (1, 1, 4, 14, 60)
# (1, 1, 4, 1, 2, 14, 48)
# (1, 1, 4, 1, 2, 14, 48)

# %%
from src.utils.plots import plot_symbols, plot_channel_frequency_domain


plot_channel_frequency_domain(
    h_freq[0, 0, 0, 0, 0].numpy().real.T,
)

# %%
plot_symbols(response_matrix[0, 0, 0].numpy().real.T)

# %%
plot_symbols(pilot_matrix[0, 0, 0, 0, 0].real.T)
